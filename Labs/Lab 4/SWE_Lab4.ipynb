# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# !pip install -r requirements.txt
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Ueqo0jT12Hxdh7Y4yZPw")
project = rf.workspace("ticon-system-ltd-8wqla").project("clownfish-iu1tl")
version = project.version(1)
dataset = version.download("yolov5")

# %%
# !python train.py --img 640 \
                 --batch 8 \
                 --epochs 5 \
                 --data /content/yolov5/Clownfish-1/data.yaml \
                 --weights yolov5s.pt \
                 --name clownfish_yolov5s

# %%
# !python detect.py \
  --weights runs/train/redpanda_yolov5s/weights/best.pt \
  --img 512 \
  --source /content/yolov5/SWE_HW4-2/test/images \
  --data /content/yolov5/SWE_HW4-2/data.yaml

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/exp/*.jpg'):
    display(Image(filename=image_path))
